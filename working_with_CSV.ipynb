# %%
import pandas as pd

# %%
df = pd.read_csv('sample.tsv', sep='\t', header=1, usecols=['JANUARY', 'FEBRUARY', 'MARCH'])

# %%
df
# Out:
#     JANUARY  FEBRUARY      MARCH
# 0         S         S          S
# 1       NaN       NaN        NaN
# 2         2         6          6
# 3         9        13         13
# 4        16        20         20
# 5        23        27         27
# 6        30       NaN        NaN
# 7       NaN       NaN        NaN
# 8    APRIL        MAY       JUNE
# 9         S         S          S
# 10      NaN         1        NaN
# 11        3         8          5
# 12       10        15         12
# 13       17        22         19
# 14       24        29         26
# 15      NaN       NaN        NaN
# 16      NaN       NaN        NaN
# 17     JULY    AUGUST  SEPTEMBER
# 18        S         S          S
# 19      NaN       NaN        NaN
# 20        3         7          4
# 21       10        14         11
# 22       17        21         18
# 23       24        28         25
# 24       31       NaN        NaN
# 25      NaN       NaN        NaN
# 26  OCTOBER  NOVEMBER   DECEMBER
# ...

# %% [markdown]
# ### skip rows

# %%
df = pd.read_csv('smartphones.csv')
df
# Out:
#                                             Smartphone     Brand  \
# 0                   Realme C55 8/256GB Sunshower Libre    Realme
# 1             Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung
# 2         Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola
# 3             Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi
# 4              Nothing Phone (2) 12/512GB Blanco Libre   Nothing
# ...                                                ...       ...
# 1811             Xiaomi Redmi Note 8 4/64GB Azul Libre    Xiaomi
# 1812   Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre    Xiaomi
# 1813          Xiaomi Redmi Note 9 4/128GB Blanco Libre    Xiaomi
# 1814   Xiaomi Redmi Note 9S 4/64GB Dual SIM Gris Libre    Xiaomi
# 1815  Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre    Xiaomi
#
#                Model   RAM  Storage   Color Free  Final Price
# 0                C55   8.0    256.0  Yellow  Yes       231.60
# ...

# %%
df = pd.read_csv('smartphones.csv', skiprows=[1815, 1816])
df
# Out:
#                                              Smartphone     Brand  \
# 0                    Realme C55 8/256GB Sunshower Libre    Realme
# 1              Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung
# 2          Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola
# 3              Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi
# 4               Nothing Phone (2) 12/512GB Blanco Libre   Nothing
# ...                                                 ...       ...
# 1809  Xiaomi Redmi Note 10 Pro 8/128GB Azul Libre + ...    Xiaomi
# 1810            Xiaomi Redmi Note 8 4/128GB Negro Libre    Xiaomi
# 1811              Xiaomi Redmi Note 8 4/64GB Azul Libre    Xiaomi
# 1812    Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre    Xiaomi
# 1813           Xiaomi Redmi Note 9 4/128GB Blanco Libre    Xiaomi
#
#                Model   RAM  Storage   Color Free  Final Price
# 0                C55   8.0    256.0  Yellow  Yes       231.60
# ...

# %%
df = pd.read_csv('smartphones.csv', nrows=100)
df
# Out:
#                                            Smartphone     Brand  \
# 0                  Realme C55 8/256GB Sunshower Libre    Realme
# 1            Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung
# 2        Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola
# 3            Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi
# 4             Nothing Phone (2) 12/512GB Blanco Libre   Nothing
# ..                                                ...       ...
# 95       Nothing Phone (2) 12/512GB Gris Oscuro Libre   Nothing
# 96                    POCO F5 5G 12/256GB Negro Libre      POCO
# 97  Xiaomi Redmi Note 11 Pro Plus 5G 8/256GB Azul ...    Xiaomi
# 98           Samsung Galaxy M53 5G 8/128GB Azul Libre   Samsung
# 99          Samsung Galaxy M53 5G 8/128GB Verde Libre   Samsung
#
#              Model   RAM  Storage   Color Free  Final Price
# 0              C55   8.0      256  Yellow  Yes       231.60
# 1       Galaxy M23   4.0      128    Blue  Yes       279.00
# ...

# %%
df = pd.read_csv('smartphones.csv')
df['Final Price'] = df['Final Price'].fillna(0).astype(int)

df
# Out:
#                                             Smartphone     Brand  \
# 0                   Realme C55 8/256GB Sunshower Libre    Realme
# 1             Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung
# 2         Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola
# 3             Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi
# 4              Nothing Phone (2) 12/512GB Blanco Libre   Nothing
# ...                                                ...       ...
# 1811             Xiaomi Redmi Note 8 4/64GB Azul Libre    Xiaomi
# 1812   Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre    Xiaomi
# 1813          Xiaomi Redmi Note 9 4/128GB Blanco Libre    Xiaomi
# 1814   Xiaomi Redmi Note 9S 4/64GB Dual SIM Gris Libre    Xiaomi
# 1815  Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre    Xiaomi
#
#                Model   RAM  Storage   Color Free  Final Price
# 0                C55   8.0    256.0  Yellow  Yes          231
# ...

# %%
df =pd.read_csv('smartphones.csv', na_values=['Blue'])
df
# Out:
#                                             Smartphone     Brand  \
# 0                   Realme C55 8/256GB Sunshower Libre    Realme
# 1             Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung
# 2         Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola
# 3             Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi
# 4              Nothing Phone (2) 12/512GB Blanco Libre   Nothing
# ...                                                ...       ...
# 1811             Xiaomi Redmi Note 8 4/64GB Azul Libre    Xiaomi
# 1812   Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre    Xiaomi
# 1813          Xiaomi Redmi Note 9 4/128GB Blanco Libre    Xiaomi
# 1814   Xiaomi Redmi Note 9S 4/64GB Dual SIM Gris Libre    Xiaomi
# 1815  Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre    Xiaomi
#
#                Model   RAM  Storage   Color Free  Final Price
# 0                C55   8.0    256.0  Yellow  Yes       231.60
# ...

# %%
dfs = pd.read_csv('smartphones.csv', chunksize=400)

for chunks in dfs:
     print(chunk.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 4
#       1 dfs = pd.read_csv('smartphones.csv', chunksize=400)
#       3 for chunks in dfs:
# ----> 4      print(chunk.shape)
#
# NameError: name 'chunk' is not defined
