# %%
import numpy as np
x=np.linspace(-40,40,100)

# %%
x.size
# Out:
# 100

# %%
y=np.sin(x)

# %% [markdown]
# y.size

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(x,y)

# %%
y=x*x+2*x+6

# %%
plt.plot(x,y)

# %% [markdown]
# Brodcasting:

# %%
a=np.arange(8).reshape(2,4)
b=np.arange(8,16).reshape(2,4)
a+b
# Out:
# array([[ 8, 10, 12, 14],
#        [16, 18, 20, 22]])

# %%
a
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 6, 7]])

# %%
b
# Out:
# array([[ 8,  9, 10, 11],
#        [12, 13, 14, 15]])

# %%
a+b
# Out:
# array([[ 8, 10, 12, 14],
#        [16, 18, 20, 22]])

# %%
a1=np.arange(3).reshape(1,3)

# %%
a1
# Out:
# array([[0, 1, 2]])

# %%
b1=np.arange(6).reshape(2,3)
b1
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
a1+b1
# Out:
# array([[0, 2, 4],
#        [3, 5, 7]])

# %%
a2=np.arange(6).reshape(3,2)
b2=np.arange(6).reshape(2,3)
a2+b2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 a2=np.arange(6).reshape(3,2)
#       2 b2=np.arange(6).reshape(2,3)
# ----> 3 a2+b2
#
# ValueError: operands could not be broadcast together with shapes (3,2) (2,3)

# %%
a2=np.arange(3).reshape(3,1)
b2=np.arange(3).reshape(1,3)
a2+b2
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4]])
