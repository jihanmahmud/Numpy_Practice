# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('smartphones.csv')
df
# Out:
#                                             Smartphone     Brand  \
# 0                   Realme C55 8/256GB Sunshower Libre    Realme
# 1             Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung
# 2         Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola
# 3             Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi
# 4              Nothing Phone (2) 12/512GB Blanco Libre   Nothing
# ...                                                ...       ...
# 1811             Xiaomi Redmi Note 8 4/64GB Azul Libre    Xiaomi
# 1812   Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre    Xiaomi
# 1813          Xiaomi Redmi Note 9 4/128GB Blanco Libre    Xiaomi
# 1814   Xiaomi Redmi Note 9S 4/64GB Dual SIM Gris Libre    Xiaomi
# 1815  Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre    Xiaomi
#
#                Model   RAM  Storage   Color Free  Final Price
# 0                C55   8.0    256.0  Yellow  Yes       231.60
# ...

# %%
df = pd.read_csv('smartphones.csv', usecols=['Smartphone', 'Model', 'RAM'])
df
# Out:
#                                             Smartphone           Model   RAM
# 0                   Realme C55 8/256GB Sunshower Libre             C55   8.0
# 1             Samsung Galaxy M23 5G 4/128GB Azul Libre      Galaxy M23   4.0
# 2         Motorola Moto G13 4/128GB Azul Lavanda Libre        Moto G13   4.0
# 3             Xiaomi Redmi Note 11S 6/128GB Gris Libre  Redmi Note 11S   6.0
# 4              Nothing Phone (2) 12/512GB Blanco Libre       Phone (2)  12.0
# ...                                                ...             ...   ...
# 1811             Xiaomi Redmi Note 8 4/64GB Azul Libre    Redmi Note 8   4.0
# 1812   Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre   Redmi Note 8T   4.0
# 1813          Xiaomi Redmi Note 9 4/128GB Blanco Libre    Redmi Note 9   4.0
# 1814   Xiaomi Redmi Note 9S 4/64GB Dual SIM Gris Libre         Note 9S   4.0
# 1815  Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre         Note 9S   6.0
#
# [1816 rows x 3 columns]

# %% [markdown]
# ### Changes the column datatype.

# %%
df = pd.read_csv('smartphones.csv', usecols=['Smartphone', 'Model', 'RAM'], )
df['RAM']=df['RAM'].fillna(0).astype(int)

# %%
df
# Out:
#                                             Smartphone           Model  RAM
# 0                   Realme C55 8/256GB Sunshower Libre             C55    8
# 1             Samsung Galaxy M23 5G 4/128GB Azul Libre      Galaxy M23    4
# 2         Motorola Moto G13 4/128GB Azul Lavanda Libre        Moto G13    4
# 3             Xiaomi Redmi Note 11S 6/128GB Gris Libre  Redmi Note 11S    6
# 4              Nothing Phone (2) 12/512GB Blanco Libre       Phone (2)   12
# ...                                                ...             ...  ...
# 1811             Xiaomi Redmi Note 8 4/64GB Azul Libre    Redmi Note 8    4
# 1812   Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre   Redmi Note 8T    4
# 1813          Xiaomi Redmi Note 9 4/128GB Blanco Libre    Redmi Note 9    4
# 1814   Xiaomi Redmi Note 9S 4/64GB Dual SIM Gris Libre         Note 9S    4
# 1815  Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre         Note 9S    6
#
# [1816 rows x 3 columns]

# %%
import mysql.connector

# %%
conn=mysql.connector.connect(host='localhost', user='root', password='', database='world')

# %%
conn

# %%
df= pd.read_sql_query('select * from country', conn)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12044\3855403162.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df= pd.read_sql_query('select * from country', conn)

# %%
df
# Out:
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# 235  YUG    Yugoslavia         Europe            Southern Europe     102173.0
# 236  ZAF  South Africa         Africa            Southern Africa    1221037.0
# 237  ZMB        Zambia         Africa             Eastern Africa     752618.0
# 238  ZWE      Zimbabwe         Africa             Eastern Africa     390757.0
#
# ...

# %%
query = "SELECT Name, Region, GNP FROM country"

# %%
df= pd.read_sql_query( query , conn)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df= pd.read_sql_query( query , conn)
#       2 df
#
# NameError: name 'query' is not defined

# %%
# !pip install sqlalchemy
